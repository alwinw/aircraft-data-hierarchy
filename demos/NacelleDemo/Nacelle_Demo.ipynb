# %% [markdown]
# # Aircraft Data Hierarchy Nacelle Demonstration

# %% [markdown]
# ## Purpose
#
# The Nacelle Demo v2 is designed to demonstrate the process of loading, manipulating, and visualizing the geometry of a nacelle component within an aircraft system. This demonstration showcases the use of Pydantic models for data validation and parsing, as well as the traversal and modification of nested attributes within a complex data hierarchy.

# %% [markdown]
# ## Summary of Demo

# %% [markdown]
# ### JSON Data Loading
# The demonstration begins by loading a JSON file [aircraft_system.json](aircraft_system.json) that contains the hierarchical data structure of an aircraft system, including the nacelle component.

# %% [markdown]
# ### Pydantic Models
# The JSON data is parsed into Pydantic models to ensure data validation and to facilitate easy access and manipulation of the nested attributes.

# %% [markdown]
# ### Attribute Traversal and Modification
# The demonstration includes functions to traverse and modify nested attributes within the Pydantic models, handling both dictionaries and Pydantic objects.

# %% [markdown]
# ### Geometry Scaling
# The nacelle geometry is extracted, scaled by a specified factor, and then updated within the data hierarchy.

# %% [markdown]
# ### Visualization
# The scaled nacelle geometry is visualized using Matplotlib to provide a graphical representation of the changes.

# %% [markdown]
# ## Example ADH JSON file

# %% [markdown]
# File [aircraft_system.json](aircraft_system.json) is an example ADH JSON file for testing. Below is a copy of the Nacelle section of the JSON file. This is only a subsection of the full input file and intended for demonstrating the Nacelle definition.

# %% [markdown]
# ```json
# {
#   "AircraftSystem": {
#     "wbs_no": "1.0",
#     "AirVehicle": {
#       "Airframe": {
#         "Nacelle": {
#           "wbs_no": "1.2.2.5",
#           "BasicStructure": {
#             "wbs_no": "1.2.2.5.1",
#           "geometry": {
#             "reference_axis": {
#               "points": [
#                 {"x": 1.0, "y": 1.0, "z": 1.0},
#                 {"x": 1.0, "y": 1.0, "z": 1.0},
#                 {"x": 1.0, "y": 1.0, "z": 1.0}
#               ],
#               "degree": 3
#             },
#             "cross_sections": [
#               {
#                 "station": 0.0,
#                 "upper_curve": {
#                   "points": [
#                     {"x": 0.0, "y": 0.5, "z": 0.0},
#                     {"x": 0.0, "y": 0.0, "z": 0.4},
#                     {"x": 0.0, "y": -0.5, "z": 0.0}
#                   ],
#                   "degree": 3
#                 },
#                 "lower_curve": {
#                   "points": [
#                     {"x": 0.0, "y": 0.5, "z": 0.0},
#                     {"x": 0.0, "y": 0.0, "z": -0.4},
#                     {"x": 0.0, "y": -0.5, "z": 0.0}
#                   ],
#                   "degree": 3
#                 }
#               },
#               {
#                 "station": 1.0,
#                 "upper_curve": {
#                   "points": [
#                     {"x": 0.5, "y": 0.5, "z": 0.0},
#                     {"x": 0.5, "y": 0.0, "z": 0.5},
#                     {"x": 0.5, "y": -0.5, "z": 0.0}
#                   ],
#                   "degree": 3
#                 },
#                 "lower_curve": {
#                   "points": [
#                     {"x": 0.5, "y": 0.5, "z": 0.0},
#                     {"x": 0.5, "y": 0.0, "z": -0.5},
#                     {"x": 0.5, "y": -0.5, "z": 0.0}
#                   ],
#                   "degree": 3
#                 }
#               },
#               {
#                 "station": 2.0,
#                 "upper_curve": {
#                   "points": [
#                     {"x": 1.0, "y": 0.5, "z": 0.0},
#                     {"x": 1.0, "y": 0.0, "z": 0.3},
#                     {"x": 1.0, "y": -0.5, "z": 0.0}
#                   ],
#                   "degree": 3
#                 },
#                 "lower_curve": {
#                   "points": [
#                     {"x": 1.0, "y": 0.5, "z": 0.0},
#                     {"x": 1.0, "y": 0.0, "z": -0.3},
#                     {"x": 1.0, "y": -0.5, "z": 0.0}
#                   ],
#                   "degree": 3
#                 }
#               }
#             ]
#           },
#           "parameters": {
#             "length": 2.0,
#             "diameter": 1.0,
#             "material": "Aluminum Alloy",
#             "weight": 500.0
#           },
#           "metadata": {
#             "key": "nacelle_metadata",
#             "value": "Example metadata for nacelle"
#           }
#         }
#     }
#   }
# }
# ```

# %% [markdown]
# ## Helper Functions

# %%
import json
import pprint
from typing import Any, Dict
from pydantic import ValidationError
import matplotlib.pyplot as plt
from adh.wbs import AircraftSystem

# %% [markdown]
# These functions are included here for now but will eventually make it into the aircraft-data-hierarchy package

# %%
# ToDo: Consider moving the next two functions into common_base_model.py
def get_nested_attr(obj: Any, attr: str) -> Any:
    """
    Traverse the object tree using dot notation to get a nested attribute.

    :param obj: The root object to start traversal from.
    :param attr: The dot notation string representing the path to the attribute.
    :return: The value of the nested attribute.
    :raises AttributeError: If any part of the path is invalid.
    """
    try:
        for part in attr.split("."):
            if isinstance(obj, dict):
                obj = obj[part]
            else:
                obj = getattr(obj, part)
        return obj
    except (AttributeError, KeyError) as e:
        raise AttributeError(f"Failed to get attribute '{attr}': {e}")


def put_nested_attr(obj: Any, attr: str, value: Any) -> None:
    """
    Traverse the object tree using dot notation to put a nested attribute.

    :param obj: The root object to start traversal from.
    :param attr: The dot notation string representing the path to the attribute.
    :param value: The value to set at the nested attribute.
    :raises AttributeError: If any part of the path is invalid.
    """
    try:
        attrs = attr.split(".")
        for part in attrs[:-1]:
            if isinstance(obj, dict):
                obj = obj[part]
            else:
                obj = getattr(obj, part)
        if isinstance(obj, dict):
            obj[attrs[-1]] = value
        else:
            setattr(obj, attrs[-1], value)
    except (AttributeError, KeyError) as e:
        raise AttributeError(f"Failed to put attribute '{attr}': {e}")


def load_aliases(file_path: str) -> Dict[str, str]:
    """
    Load aliases from a file.

    :param file_path: Path to the file containing aliases.
    :return: A dictionary of aliases.
    """
    with open(file_path, "r") as file:
        aliases = {}
        for line in file:
            key, value = line.strip().split("=")
            aliases[key.strip()] = value.strip().strip('"')  # Remove extra quotes
    return aliases


# Function to scale the nacelle geometry
def scale_nacelle_geometry(
    geometry: Dict[str, Any], scale_factor: float
) -> Dict[str, Any]:
    def scale_point(point: Dict[str, float]) -> Dict[str, float]:
        return {k: v * scale_factor for k, v in point.items()}

    scaled_geometry = geometry.copy()
    scaled_geometry["reference_axis"]["points"] = [
        scale_point(p) for p in geometry["reference_axis"]["points"]
    ]

    for cross_section in scaled_geometry["cross_sections"]:
        cross_section["upper_curve"]["points"] = [
            scale_point(p) for p in cross_section["upper_curve"]["points"]
        ]
        cross_section["lower_curve"]["points"] = [
            scale_point(p) for p in cross_section["lower_curve"]["points"]
        ]

    return scaled_geometry


# Function to draw the nacelle geometry
def draw_nacelle_geometry(geometry: Dict[str, Any]):
    fig, ax = plt.subplots()

    # Plot the reference axis
    ref_axis_points = geometry.get("reference_axis", {}).get("points", [])
    if ref_axis_points:
        ref_axis_x = [point["x"] for point in ref_axis_points]
        ref_axis_y = [point["y"] for point in ref_axis_points]
        ax.plot(ref_axis_x, ref_axis_y, label="Reference Axis", color="blue")

    # Plot the cross-sections
    cross_sections = geometry.get("cross_sections", [])
    for cross_section in cross_sections:
        station = cross_section.get("station", "Unknown")

        if "upper_curve" in cross_section and cross_section["upper_curve"]:
            upper_curve_points = cross_section["upper_curve"]["points"]
            upper_curve_x = [point["x"] for point in upper_curve_points]
            upper_curve_y = [point["y"] for point in upper_curve_points]
            ax.plot(
                upper_curve_x,
                upper_curve_y,
                label=f"Upper Curve at Station {station}",
                color="red",
            )

        if "lower_curve" in cross_section and cross_section["lower_curve"]:
            lower_curve_points = cross_section["lower_curve"]["points"]
            lower_curve_x = [point["x"] for point in lower_curve_points]
            lower_curve_y = [point["y"] for point in lower_curve_points]
            ax.plot(
                lower_curve_x,
                lower_curve_y,
                label=f"Lower Curve at Station {station}",
                color="green",
            )

    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_title("Nacelle Geometry")
    ax.legend(loc="best", fontsize="small", ncol=2)  # Improved legend
    plt.show()


# Function to extract nacelle geometry
def extract_nacelle_geometry(adh: AircraftSystem, aliases: Dict[str, str]) -> Any:
    nacelle_path = aliases.get("Nacelle")
    if not nacelle_path:
        raise KeyError("Alias for 'Nacelle' not found in aliases.")

    # Debug print statement
    print(f"Extracting geometry using path: {nacelle_path}.geometry")

    try:
        return get_nested_attr(adh, nacelle_path + ".geometry")
    except AttributeError as e:
        raise AttributeError(f"Error extracting geometry: {e}")


# Function to extract nacelle parameters
def extract_nacelle_parameters(adh: AircraftSystem, aliases: Dict[str, str]) -> Any:
    nacelle_path = aliases.get("Nacelle")
    if not nacelle_path:
        raise KeyError("Alias for 'Nacelle' not found in aliases.")

    # Debug print statement
    print(f"Extracting parameters using path: {nacelle_path}.parameters")

    try:
        return get_nested_attr(adh, nacelle_path + ".parameters")
    except AttributeError as e:
        raise AttributeError(f"Error extracting parameters: {e}")

# %% [markdown]
# ## Code Implementation

# %% [markdown]
# ### 1. Loading JSON Data
#
# The JSON file [aircraft_system.json](aircraft_system.json) is loaded into a Python dictionary.

# %%
# Load the ADH JSON file
with open("aircraft_system.json", "r") as file:
    aircraft_system_data = json.load(file)

# %% [markdown]
# The JSON data is then parsed into the `AircraftSystem` Pydantic model to ensure data validation and to facilitate easy access to nested attributes.

# %%
# Parse the JSON data into the Pydantic model
adh = AircraftSystem.model_validate(aircraft_system_data)

# %%
pprint.pprint(adh.model_dump(), width=120)
# Out:
# {'AircraftSystem': {'AirVehicle': {'AirVehicleIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.2.1'},
#                                    'AirVehicleSoftwareRelease': {'wbs_no': '1.2.9'},
#                                    'Airframe': {'AirframeIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.2.2.1'},
#                                                 'Empennage': {'Stabilizer': {'Ailerons': {'wbs_no': '1.2.2.4.3'},
#                                                                              'BasicStructure': {'CenterSection': {'Clips': {'wbs_no': '1.2.2.4.1.1.1.5'},
#                                                                                                                   'Ribs': {'wbs_no': '1.2.2.4.1.1.1.3'},
#                                                                                                                   'Skins': {'wbs_no': '1.2.2.4.1.1.1.1'},
#                                                                                                                   'Spars': {'wbs_no': '1.2.2.4.1.1.1.2'},
#                                                                                                                   'Stringers': {'wbs_no': '1.2.2.4.1.1.1.4'},
#                                                                                                                   'wbs_no': '1.2.2.4.1.1.1'},
#                                                                                                 'IntermediatePanel': {'Clips': {'wbs_no': '1.2.2.4.1.1.2.5'},
#                                                                                                                       'Ribs': {'wbs_no': '1.2.2.4.1.1.2.3'},
#                                                                                                                       'Skins': {'wbs_no': '1.2.2.4.1.1.2.1'},
#                                                                                                                       'Spars': {'wbs_no': '1.2.2.4.1.1.2.2'},
#                                                                                                                       'Stringers': {'wbs_no': '1.2.2.4.1.1.2.4'},
#                                                                                                                       'wbs_no': '1.2.2.4.1.1.2'},
#                                                                                                 'OuterPanel': {'Clips': {'wbs_no': '1.2.2.4.1.1.3.5'},
#                                                                                                                'Ribs': {'wbs_no': '1.2.2.4.1.1.3.3'},
#                                                                                                                'Skins': {'wbs_no': '1.2.2.4.1.1.3.1'},
#                                                                                                                'Spars': {'wbs_no': '1.2.2.4.1.1.3.2'},
#                                                                                                                'Stringers': {'wbs_no': '1.2.2.4.1.1.3.4'},
#                                                                                                                'wbs_no': '1.2.2.4.1.1.3'},
#                                                                                                 'wbs_no': '1.2.2.4.1.1'},
#                                                                              'Elevons': {'wbs_no': '1.2.2.4.4'},
#                                                                              'LeadingEdgeFlaps': {'wbs_no': '1.2.2.4.7'},
#                                                                              'SecondaryStructure': {'AccessPanels': {'wbs_no': '1.2.2.4.2.1'},
#                                                                                                     'wbs_no': '1.2.2.4.2'},
#                                                                              'Slats': {'wbs_no': '1.2.2.4.8'},
#                                                                              'Spoilers': {'wbs_no': '1.2.2.4.5'},
#                                                                              'TrailingEdgeFlaps': {'wbs_no': '1.2.2.4.6'},
#                                                                              'wbs_no': '1.2.2.4.1'},
#                                                               'wbs_no': '1.2.2.4'},
#                                                 'Fuselage': {'BasicStructure': {'Beams': {'wbs_no': '1.2.2.2.1.5'},
#                                                                                 'Bulkheads': {'wbs_no': '1.2.2.2.1.7'},
#                                                                                 'Clips': {'wbs_no': '1.2.2.2.1.4'},
#                                                                                 'Floors': {'wbs_no': '1.2.2.2.1.6'},
#                                                                                 'Frames': {'wbs_no': '1.2.2.2.1.3'},
#                                                                                 'Longerons': {'wbs_no': '1.2.2.2.1.8'},
#                                                                                 'Skins': {'wbs_no': '1.2.2.2.1.1'},
#                                                                                 'Stringers': {'wbs_no': '1.2.2.2.1.2'},
#                                                                                 'Supports': {'wbs_no': '1.2.2.2.1.9'},
#                                                                                 'wbs_no': '1.2.2.2.1'},
#                                                              'SecondaryStructure': {'Doors': {'wbs_no': '1.2.2.2.2.5'},
#                                                                                     'Enclosures': {'wbs_no': '1.2.2.2.2.1'},
#                                                                                     'Flooring': {'wbs_no': '1.2.2.2.2.2'},
#                                                                                     'Misc': {'wbs_no': '1.2.2.2.2.8'},
#                                                                                     'Panels': {'wbs_no': '1.2.2.2.2.7'},
#                                                                                     'Partitions': {'wbs_no': '1.2.2.2.2.3'},
#                                                                                     'Ramps': {'wbs_no': '1.2.2.2.2.6'},
#                                                                                     'Windows': {'wbs_no': '1.2.2.2.2.4'},
#                                                                                     'wbs_no': '1.2.2.2.2'},
#                                                              'wbs_no': '1.2.2.2'},
#                                                 'Nacelle': {'BasicStructure': {'Beams': {'wbs_no': '1.2.2.5.1.5'},
#                                                                                'Bulkheads': {'wbs_no': '1.2.2.5.1.7'},
#                                                                                'Clips': {'wbs_no': '1.2.2.5.1.4'},
#                                                                                'Floors': {'wbs_no': '1.2.2.5.1.6'},
#                                                                                'Frames': {'wbs_no': '1.2.2.5.1.3'},
#                                                                                'Longerons': {'wbs_no': '1.2.2.5.1.8'},
#                                                                                'Skins': {'wbs_no': '1.2.2.5.1.1'},
#                                                                                'Stringers': {'wbs_no': '1.2.2.5.1.2'},
#                                                                                'Supports': {'wbs_no': '1.2.2.5.1.9'},
#                                                                                'wbs_no': '1.2.2.5.1'},
#                                                             'SecondaryStructure': {'Doors': {'wbs_no': '1.2.2.5.2.5'},
#                                                                                    'Enclosures': {'wbs_no': '1.2.2.5.2.1'},
#                                                                                    'Flooring': {'wbs_no': '1.2.2.5.2.2'},
#                                                                                    'Misc': {'wbs_no': '1.2.2.5.2.8'},
#                                                                                    'Panels': {'wbs_no': '1.2.2.5.2.7'},
#                                                                                    'Partitions': {'wbs_no': '1.2.2.5.2.3'},
#                                                                                    'Ramps': {'wbs_no': '1.2.2.5.2.6'},
#                                                                                    'Windows': {'wbs_no': '1.2.2.5.2.4'},
#                                                                                    'wbs_no': '1.2.2.5.2'},
#                                                             'geometry': {'cross_sections': [{'lower_curve': {'degree': 3,
#                                                                                                              'points': [{'x': 0.0,
#                                                                                                                          'y': 0.5,
#                                                                                                                          'z': 0.0},
#                                                                                                                         {'x': 0.0,
#                                                                                                                          'y': 0.0,
#                                                                                                                          'z': -0.4},
#                                                                                                                         {'x': 0.0,
#                                                                                                                          'y': -0.5,
#                                                                                                                          'z': 0.0}]},
#                                                                                              'station': 0.0,
#                                                                                              'upper_curve': {'degree': 3,
#                                                                                                              'points': [{'x': 0.0,
#                                                                                                                          'y': 0.5,
#                                                                                                                          'z': 0.0},
#                                                                                                                         {'x': 0.0,
#                                                                                                                          'y': 0.0,
#                                                                                                                          'z': 0.4},
#                                                                                                                         {'x': 0.0,
#                                                                                                                          'y': -0.5,
#                                                                                                                          'z': 0.0}]}},
#                                                                                             {'lower_curve': {'degree': 3,
#                                                                                                              'points': [{'x': 0.5,
#                                                                                                                          'y': 0.5,
#                                                                                                                          'z': 0.0},
#                                                                                                                         {'x': 0.5,
#                                                                                                                          'y': 0.0,
#                                                                                                                          'z': -0.5},
#                                                                                                                         {'x': 0.5,
#                                                                                                                          'y': -0.5,
#                                                                                                                          'z': 0.0}]},
#                                                                                              'station': 1.0,
#                                                                                              'upper_curve': {'degree': 3,
#                                                                                                              'points': [{'x': 0.5,
#                                                                                                                          'y': 0.5,
#                                                                                                                          'z': 0.0},
#                                                                                                                         {'x': 0.5,
#                                                                                                                          'y': 0.0,
#                                                                                                                          'z': 0.5},
#                                                                                                                         {'x': 0.5,
#                                                                                                                          'y': -0.5,
#                                                                                                                          'z': 0.0}]}},
#                                                                                             {'lower_curve': {'degree': 3,
#                                                                                                              'points': [{'x': 1.0,
#                                                                                                                          'y': 0.5,
#                                                                                                                          'z': 0.0},
#                                                                                                                         {'x': 1.0,
#                                                                                                                          'y': 0.0,
#                                                                                                                          'z': -0.3},
#                                                                                                                         {'x': 1.0,
#                                                                                                                          'y': -0.5,
#                                                                                                                          'z': 0.0}]},
#                                                                                              'station': 2.0,
#                                                                                              'upper_curve': {'degree': 3,
#                                                                                                              'points': [{'x': 1.0,
#                                                                                                                          'y': 0.5,
#                                                                                                                          'z': 0.0},
#                                                                                                                         {'x': 1.0,
#                                                                                                                          'y': 0.0,
#                                                                                                                          'z': 0.3},
#                                                                                                                         {'x': 1.0,
#                                                                                                                          'y': -0.5,
#                                                                                                                          'z': 0.0}]}}],
#                                                                          'reference_axis': {'degree': 3,
#                                                                                             'points': [{'x': 1.0,
#                                                                                                         'y': 1.0,
#                                                                                                         'z': 1.0},
#                                                                                                        {'x': 1.0,
#                                                                                                         'y': 1.0,
#                                                                                                         'z': 1.0},
#                                                                                                        {'x': 1.0,
#                                                                                                         'y': 1.0,
#                                                                                                         'z': 1.0}]}},
#                                                             'metadata': {'key': 'nacelle_metadata',
#                                                                          'value': 'Example metadata for nacelle'},
#                                                             'parameters': {'diameter': 1.0,
#                                                                            'length': 2.0,
#                                                                            'material': 'Aluminum Alloy',
#                                                                            'weight': 500.0},
#                                                             'wbs_no': '1.2.2.5'},
#                                                 'Propulsion': {'AccessoryGearBoxesAndDrive': {'wbs_no': '1.2.3.3'},
#                                                                'DriveSystem': {'GasDrive': {'wbs_no': '1.2.3.12.6'},
#                                                                                'GearBoxes': {'wbs_no': '1.2.3.12.1'},
#                                                                                'LubSys': {'wbs_no': '1.2.3.12.2'},
#                                                                                'RotorShaft': {'wbs_no': '1.2.3.12.5'},
#                                                                                'RtrBrk': {'wbs_no': '1.2.3.12.3'},
#                                                                                'TransmissionDrive': {'wbs_no': '1.2.3.12.4'},
#                                                                                'wbs_no': '1.2.3.12'},
#                                                                'Engine': {'wbs_no': '1.2.3.1'},
#                                                                'EngineControls': {'wbs_no': '1.2.3.7'},
#                                                                'EngineCooling': {'wbs_no': '1.2.3.5'},
#                                                                'EngineInstallation': {'wbs_no': '1.2.3.2'},
#                                                                'ExhaustSystem': {'wbs_no': '1.2.3.4'},
#                                                                'FuelSystem': {'Etc': {'wbs_no': '1.2.3.11.4'},
#                                                                               'Plumbing': {'wbs_no': '1.2.3.11.3'},
#                                                                               'ProtectedTanks': {'wbs_no': '1.2.3.11.1'},
#                                                                               'UnprotectedTanks': {'wbs_no': '1.2.3.11.2'},
#                                                                               'wbs_no': '1.2.3.11'},
#                                                                'LubricatingSystem': {'wbs_no': '1.2.3.10'},
#                                                                'PropellerOrFanInstallation': {'wbs_no': '1.2.3.9'},
#                                                                'StartingSystem': {'wbs_no': '1.2.3.8'},
#                                                                'WaterInjection': {'wbs_no': '1.2.3.6'},
#                                                                'wbs_no': '1.2.3'},
#                                                 'Wing': {'Ailerons': {'wbs_no': '1.2.2.3.3'},
#                                                          'BasicStructure': {'CenterSection': {'Clips': {'wbs_no': '1.2.2.3.1.1.5'},
#                                                                                               'Ribs': {'wbs_no': '1.2.2.3.1.1.3'},
#                                                                                               'Skins': {'wbs_no': '1.2.2.3.1.1.1'},
#                                                                                               'Spars': {'wbs_no': '1.2.2.3.1.1.2'},
#                                                                                               'Stringers': {'wbs_no': '1.2.2.3.1.1.4'},
#                                                                                               'wbs_no': '1.2.2.3.1.1'},
#                                                                             'IntermediatePanel': {'Clips': {'wbs_no': '1.2.2.3.1.2.5'},
#                                                                                                   'Ribs': {'wbs_no': '1.2.2.3.1.2.3'},
#                                                                                                   'Skins': {'wbs_no': '1.2.2.3.1.2.1'},
#                                                                                                   'Spars': {'wbs_no': '1.2.2.3.1.2.2'},
#                                                                                                   'Stringers': {'wbs_no': '1.2.2.3.1.2.4'},
#                                                                                                   'wbs_no': '1.2.2.3.1.2'},
#                                                                             'OuterPanel': {'Clips': {'wbs_no': '1.2.2.3.1.3.5'},
#                                                                                            'Ribs': {'wbs_no': '1.2.2.3.1.3.3'},
#                                                                                            'Skins': {'wbs_no': '1.2.2.3.1.3.1'},
#                                                                                            'Spars': {'wbs_no': '1.2.2.3.1.3.2'},
#                                                                                            'Stringers': {'wbs_no': '1.2.2.3.1.3.4'},
#                                                                                            'wbs_no': '1.2.2.3.1.3'},
#                                                                             'wbs_no': '1.2.2.3.1'},
#                                                          'Elevons': {'wbs_no': '1.2.2.3.4'},
#                                                          'LeadingEdgeFlaps': {'wbs_no': '1.2.2.3.7'},
#                                                          'SecondaryStructure': {'AccessPanels': {'wbs_no': '1.2.2.3.2.1'},
#                                                                                 'wbs_no': '1.2.2.3.2'},
#                                                          'Slats': {'wbs_no': '1.2.2.3.8'},
#                                                          'Spoilers': {'wbs_no': '1.2.2.3.5'},
#                                                          'TrailingEdgeFlaps': {'wbs_no': '1.2.2.3.6'},
#                                                          'wbs_no': '1.2.2.3'},
#                                                 'wbs_no': '1.2.2'},
#                                    'ArmamentWeaponsDelivery': {'wbs_no': '1.2.6'},
#                                    'AuxiliaryEquipment': {'wbs_no': '1.2.7'},
#                                    'Avionics': {'AutomaticFlightControl': {'wbs_no': '1.2.5.10'},
#                                                 'AvionicsIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.2.5.1'},
#                                                 'AvionicsSoftwareRelease': {'wbs_no': '1.2.5.13'},
#                                                 'CommunicationIdentification': {'wbs_no': '1.2.5.2'},
#                                                 'DataDisplayAndControls': {'wbs_no': '1.2.5.6'},
#                                                 'ElectronicWarfare': {'wbs_no': '1.2.5.9'},
#                                                 'FireControl': {'wbs_no': '1.2.5.5'},
#                                                 'HealthMonitoringSystem': {'wbs_no': '1.2.5.11'},
#                                                 'MissionComputerProcessing': {'wbs_no': '1.2.5.4'},
#                                                 'NavigationGuidance': {'wbs_no': '1.2.5.3'},
#                                                 'OtherAvionicsSubsystems': {'wbs_no': '1.2.5.14'},
#                                                 'Reconnaissance': {'wbs_no': '1.2.5.8'},
#                                                 'StoresManagement': {'wbs_no': '1.2.5.12'},
#                                                 'Survivability': {'wbs_no': '1.2.5.7'},
#                                                 'wbs_no': '1.2.5'},
#                                    'FurnishingsAndEquipment': {'AccommodationForPersonnel': {'wbs_no': '1.2.8.1'},
#                                                                'EmergencyEquipment': {'wbs_no': '1.2.8.4'},
#                                                                'Furnishings': {'wbs_no': '1.2.8.3'},
#                                                                'MiscellaneousEquipment': {'wbs_no': '1.2.8.2'},
#                                                                'wbs_no': '1.2.8'},
#                                    'VehicleSubsystems': {'AuxiliaryPowerSubsystem': {'wbs_no': '1.2.4.3'},
#                                                          'CrewStationSubsystem': {'wbs_no': '1.2.4.6'},
#                                                          'DriveGroup': {'wbs_no': '1.2.4.11'},
#                                                          'ElectricalSubsystem': {'wbs_no': '1.2.4.5'},
#                                                          'EnvironmentalControlSubsystem': {'wbs_no': '1.2.4.7'},
#                                                          'FlightControlSubsystem': {'AutomaticFlightControlSystem': {'wbs_no': '1.2.4.2.2'},
#                                                                                     'CockpitControls': {'wbs_no': '1.2.4.2.1'},
#                                                                                     'SystemControls': {'wbs_no': '1.2.4.2.3'},
#                                                                                     'wbs_no': '1.2.4.2'},
#                                                          'FuelSubsystem': {'wbs_no': '1.2.4.8'},
#                                                          'HydraulicSubsystem': {'wbs_no': '1.2.4.4'},
#                                                          'LandingGear': {'wbs_no': '1.2.4.9'},
#                                                          'OtherSubsystems': {'wbs_no': '1.2.4.13'},
#                                                          'RotorGroup': {'wbs_no': '1.2.4.10'},
#                                                          'VehicleSubsystemIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.2.4.1'},
#                                                          'VehicleSubsystemSoftwareRelease': {'wbs_no': '1.2.4.12'},
#                                                          'wbs_no': '1.2.4'},
#                                    'wbs_no': '1.2'},
#                     'AircraftSystemIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.1'},
#                     'AircraftSystemSoftwareRelease': {'wbs_no': '1.5'},
#                     'CommonSupportEquipment': {'SupportAndHandlingEquipment': {'AirframeHullVehicle': {'wbs_no': '1.12.2.1'},
#                                                                                'ElectronicsAvionics': {'wbs_no': '1.12.2.3'},
#                                                                                'OtherMajorSubsystems': {'wbs_no': '1.12.2.4'},
#                                                                                'Propulsion': {'wbs_no': '1.12.2.2'},
#                                                                                'wbs_no': '1.12.2'},
#                                                'TestAndMeasurementEquipment': {'AirframeHullVehicle': {'wbs_no': '1.12.1.1'},
#                                                                                'ElectronicsAvionics': {'wbs_no': '1.12.1.3'},
#                                                                                'OtherMajorSubsystems': {'wbs_no': '1.12.1.4'},
#                                                                                'Propulsion': {'wbs_no': '1.12.1.2'},
#                                                                                'wbs_no': '1.12.1'},
#                                                'wbs_no': '1.12'},
#                     'ContractorLogisticsSupport': {'wbs_no': '1.14'},
#                     'Data': {'DataDeliverables': {'wbs_no': '1.10.1'},
#                              'DataRepository': {'wbs_no': '1.10.2'},
#                              'DataRights': {'wbs_no': '1.10.3'},
#                              'wbs_no': '1.10'},
#                     'GroundHostSegment': {'CommandAndControlSubsystem': {'wbs_no': '1.4.3'},
#                                           'GroundControlSystems': {'wbs_no': '1.4.2'},
#                                           'GroundSegmentIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.4.1'},
#                                           'GroundSegmentSoftwareRelease': {'wbs_no': '1.4.7'},
#                                           'LaunchEquipment': {'wbs_no': '1.4.4'},
#                                           'OtherGroundHostSegment': {'wbs_no': '1.4.8'},
#                                           'RecoveryEquipment': {'wbs_no': '1.4.5'},
#                                           'TransportVehicles': {'wbs_no': '1.4.6'},
#                                           'wbs_no': '1.4'},
#                     'IndustrialFacilities': {'ConstructionConversionExpansion': {'wbs_no': '1.15.1'},
#                                              'EquipmentAcquisitionOrModernization': {'wbs_no': '1.15.2'},
#                                              'IndustrialFacilitiesMaintenance': {'wbs_no': '1.15.3'},
#                                              'wbs_no': '1.15'},
#                     'InitialSparesAndRepairParts': {'wbs_no': '1.16'},
#                     'OperationalSiteActivation': {'ContractorTechnicalSupport': {'wbs_no': '1.13.2'},
#                                                   'InterimContractorSupport': {'wbs_no': '1.13.5'},
#                                                   'SiteConstruction': {'wbs_no': '1.13.3'},
#                                                   'SiteShipVehicleConversion': {'wbs_no': '1.13.4'},
#                                                   'SystemAssemblyInstallationAndCheckoutOnSite': {'wbs_no': '1.13.1'},
#                                                   'wbs_no': '1.13'},
#                     'PayloadMissionSystem': {'ArmamentWeaponsDeliveryPayload': {'wbs_no': '1.3.5'},
#                                              'ElectronicWarfarePayload': {'wbs_no': '1.3.4'},
#                                              'OtherPayload': {'wbs_no': '1.3.7'},
#                                              'PayloadIntegrationAssemblyTestAndCheckout': {'wbs_no': '1.3.1'},
#                                              'PayloadSoftwareRelease': {'wbs_no': '1.3.6'},
#                                              'ReconnaissancePayload': {'wbs_no': '1.3.3'},
#                                              'SurvivabilityPayload': {'wbs_no': '1.3.2'},
#                                              'wbs_no': '1.3'},
#                     'PeculiarSupportEquipment': {'SupportAndHandlingEquipment': {'AirframeHullVehicle': {'wbs_no': '1.11.2.1'},
#                                                                                  'ElectronicsAvionics': {'wbs_no': '1.11.2.3'},
#                                                                                  'OtherMajorSubsystems': {'wbs_no': '1.11.2.4'},
#                                                                                  'Propulsion': {'wbs_no': '1.11.2.2'},
#                                                                                  'wbs_no': '1.11.2'},
#                                                  'TestAndMeasurementEquipment': {'AirframeHullVehicle': {'wbs_no': '1.11.1.1'},
#                                                                                  'ElectronicsAvionics': {'wbs_no': '1.11.1.3'},
#                                                                                  'OtherMajorSubsystems': {'wbs_no': '1.11.1.4'},
#                                                                                  'Propulsion': {'wbs_no': '1.11.1.2'},
#                                                                                  'wbs_no': '1.11.1'},
#                                                  'wbs_no': '1.11'},
#                     'ProgramManagement': {'CoreProgramManagement': {'wbs_no': '1.7.4'},
#                                           'CybersecurityManagement': {'wbs_no': '1.7.3'},
#                                           'IntegratedLogisticsSupportProgramManagement': {'wbs_no': '1.7.2'},
#                                           'OtherProgramManagement': {'wbs_no': '1.7.5'},
#                                           'SoftwareProgramManagement': {'wbs_no': '1.7.1'},
#                                           'wbs_no': '1.7'},
#                     'SystemTestAndEvaluation': {'DevelopmentalTestAndEvaluation': {'CybersecurityTestAndEvaluation': {'wbs_no': '1.8.1.6'},
#                                                                                    'FlightTests': {'wbs_no': '1.8.1.4'},
#                                                                                    'GroundTests': {'wbs_no': '1.8.1.5'},
#                                                                                    'OtherDTEtests': {'wbs_no': '1.8.1.7'},
#                                                                                    'StructuralTests': {'wbs_no': '1.8.1.3'},
#                                                                                    'SystemAcceptanceTest': {'wbs_no': '1.8.1.1'},
#                                                                                    'WindTunnelTests': {'wbs_no': '1.8.1.2'},
#                                                                                    'wbs_no': '1.8.1'},
#                                                 'LiveFireTestAndEvaluation': {'wbs_no': '1.8.3'},
#                                                 'MockupsSystemIntegrationLabs': {'wbs_no': '1.8.4'},
#                                                 'OperationalTestAndEvaluation': {'CybersecurityTestAndEvaluation': {'wbs_no': '1.8.2.5'},
#                                                                                  'FlightTests': {'wbs_no': '1.8.2.3'},
#                                                                                  'GroundTests': {'wbs_no': '1.8.2.4'},
#                                                                                  'InteroperabilityTesting': {'wbs_no': '1.8.2.2'},
#                                                                                  'LimitedUserEvaluation': {'wbs_no': '1.8.2.1'},
#                                                                                  'OtherOTEtests': {'wbs_no': '1.8.2.6'},
#                                                                                  'wbs_no': '1.8.2'},
#                                                 'TestAndEvaluationSupport': {'wbs_no': '1.8.5'},
#                                                 'TestFacilities': {'wbs_no': '1.8.6'},
#                                                 'wbs_no': '1.8'},
#                     'SystemsEngineering': {'CoreSystemsEngineering': {'wbs_no': '1.6.4'},
#                                            'CybersecuritySystemsEngineering': {'wbs_no': '1.6.3'},
#                                            'IntegratedLogisticsSupportSystemsEngineering': {'wbs_no': '1.6.2'},
#                                            'OtherSystemsEngineering': {'wbs_no': '1.6.5'},
#                                            'SoftwareSystemsEngineering': {'wbs_no': '1.6.1'},
#                                            'wbs_no': '1.6'},
#                     'Training': {'Equipment': {'MaintainerInstructionalEquipment': {'wbs_no': '1.9.1.2'},
#                                                'OperatorInstructionalEquipment': {'wbs_no': '1.9.1.1'},
#                                                'wbs_no': '1.9.1'},
#                                  'Facilities': {'wbs_no': '1.9.3'},
#                                  'Services': {'MaintainerInstructionalServices': {'wbs_no': '1.9.2.2'},
#                                               'OperatorInstructionalServices': {'wbs_no': '1.9.2.1'},
#                                               'wbs_no': '1.9.2'},
#                                  'TrainingSoftware': {'wbs_no': '1.9.4'},
#                                  'wbs_no': '1.9'},
#                     'wbs_no': '1.0'},
#  'air_vehicle': None,
#  'common_support_equipment': None,
#  'contractor_logistics_support': None,
#  'data': None,
#  'description': None,
#  'ground_host_segment': None,
#  'industrial_facilities': None,
#  'initial_spares_and_repair_parts': None,
#  'integration': None,
#  'name': None,
#  'operational_site_activation': None,
#  'payload_mission_system': None,
#  'peculiar_support_equipment': None,
#  'program_management': None,
#  'software_release': None,
#  'source_info': None,
#  'system_test_and_evaluation': None,
#  'systems_engineering': None,
#  'training': None,
#  'wbs_no': '1.0'}

# %% [markdown]
# ### 2. Parsing JSON Data into Pydantic Models

# %% [markdown]
# The `AircraftSystem` model is defined using Pydantic, with nested classes representing the hierarchical structure of the aircraft system.
#
# The `Nacelle` class, which inherits from the `Component` class, includes attributes such as geometry, parameters, and metadata.

# %% [markdown]
# ### 3. Attribute Traversal and Modification

# %% [markdown]
# The `get_nested_attr()` function is used to traverse the object tree using dot notation to get a nested attribute. It handles both dictionaries and Pydantic objects.
#
# The `put_nested_attr()` function is used to traverse the object tree using dot notation to set a nested attribute. It also handles both dictionaries and Pydantic objects.

# %% [markdown]
# ### 4. Extracting and Scaling Nacelle Geometry

# %%
# Load aliases from the file
aliases = load_aliases("aircraft_data_hierarchy_aliases.txt")

# %%
pprint.pprint(aliases, width=120)
# Out:
# {'AccommodationForPersonnel': 'AircraftSystem.AirVehicle.FurnishingsAndEquipment.AccommodationForPersonnel',
#  'AirVehicle': 'AircraftSystem.AirVehicle',
#  'AirVehicleAmmunition': 'AircraftSystem.AirVehicle.Ammunition',
#  'AirVehicleCargo': 'AircraftSystem.AirVehicle.Cargo',
#  'AirVehicleContingency': 'AircraftSystem.AirVehicle.Contingency',
#  'AirVehicleExternalUsableFuel': 'AircraftSystem.AirVehicle.ExternalUsableFuel',
#  'AirVehicleIntegration': 'AircraftSystem.AirVehicle.AirVehicleIntegrationAssemblyTestAndCheckout',
#  'AirVehicleInternalUsableFuel': 'AircraftSystem.AirVehicle.InternalUsableFuel',
#  'AirVehicleOperatingItems': 'AircraftSystem.AirVehicle.OperatingItems',
#  'AirVehicleOtherAirVehicle': 'AircraftSystem.AirVehicle.OtherAirVehicle',
#  'AirVehiclePassengers': 'AircraftSystem.AirVehicle.Passengers',
#  'AirVehicleSoftwareRelease': 'AircraftSystem.AirVehicle.AirVehicleSoftwareRelease',
#  'AirVehicleTroops': 'AircraftSystem.AirVehicle.Troops',
#  'AirVehicleWeapons': 'AircraftSystem.AirVehicle.Weapons',
#  'AircraftHandling': 'AircraftSystem.AirVehicle.LoadHandlingSystem.AircraftHandling',
#  'AircraftSystem': 'AircraftSystem',
#  'AircraftSystemIntegration': 'AircraftSystem.AircraftSystemIntegrationAssemblyTestAndCheckout',
#  'AircraftSystemPayloadMissionSystem': 'AircraftSystem.PayloadMissionSystem',
#  'AircraftSystemSoftwareRelease': 'AircraftSystem.AircraftSystemSoftwareRelease',
#  'Airframe': 'AircraftSystem.AirVehicle.Airframe',
#  'AirframeIntegration': 'AircraftSystem.AirVehicle.Airframe.AirframeIntegrationAssemblyTestAndCheckout',
#  'ArmamentWeaponsDelivery': 'AircraftSystem.AirVehicle.ArmamentWeaponsDelivery',
#  'AuxiliaryEquipment': 'AircraftSystem.AirVehicle.AuxiliaryEquipment',
#  'Avionics': 'AircraftSystem.AirVehicle.Avionics',
#  'AvionicsAutomaticFlightControl': 'AircraftSystem.AirVehicle.Avionics.AutomaticFlightControl',
#  'AvionicsCommunicationIdentification': 'AircraftSystem.AirVehicle.Avionics.CommunicationIdentification',
#  'AvionicsDataDisplayAndControls': 'AircraftSystem.AirVehicle.Avionics.DataDisplayAndControls',
#  'AvionicsElectronicWarfare': 'AircraftSystem.AirVehicle.Avionics.ElectronicWarfare',
#  'AvionicsFireControl': 'AircraftSystem.AirVehicle.Avionics.FireControl',
#  'AvionicsHealthMonitoringSystem': 'AircraftSystem.AirVehicle.Avionics.HealthMonitoringSystem',
#  'AvionicsInstallation': 'AircraftSystem.AirVehicle.Avionics.Installation',
#  'AvionicsIntegration': 'AircraftSystem.AirVehicle.Avionics.AvionicsIntegrationAssemblyTestAndCheckout',
#  'AvionicsMissionComputerProcessing': 'AircraftSystem.AirVehicle.Avionics.MissionComputerProcessing',
#  'AvionicsNavigationGuidance': 'AircraftSystem.AirVehicle.Avionics.NavigationGuidance',
#  'AvionicsReconnaissance': 'AircraftSystem.AirVehicle.Avionics.Reconnaissance',
#  'AvionicsSoftwareRelease': 'AircraftSystem.AirVehicle.Avionics.AvionicsSoftwareRelease',
#  'AvionicsStoresManagement': 'AircraftSystem.AirVehicle.Avionics.StoresManagement',
#  'AvionicsSubsystems': 'AircraftSystem.AirVehicle.Avionics.OtherAvionicsSubsystems',
#  'AvionicsSurvivability': 'AircraftSystem.AirVehicle.Avionics.Survivability',
#  'Ballast': 'AircraftSystem.AirVehicle.BallastGroup',
#  'Canard': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard',
#  'CanardAccessPanels': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.SecondaryStructure.AccessPanels',
#  'CanardAilerons': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.Ailerons',
#  'CanardBasicStructure': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure',
#  'CanardCenterSection': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.CenterSection',
#  'CanardCenterSectionClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.CenterSection.Clips',
#  'CanardCenterSectionRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.CenterSection.Ribs',
#  'CanardCenterSectionSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.CenterSection.Skins',
#  'CanardCenterSectionSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.CenterSection.Spars',
#  'CanardCenterSectionStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.CenterSection.Stringers',
#  'CanardElevons': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.Elevons',
#  'CanardIntermediatePanel': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.IntermediatePanel',
#  'CanardIntermediatePanelClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.IntermediatePanel.Clips',
#  'CanardIntermediatePanelRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.IntermediatePanel.Ribs',
#  'CanardIntermediatePanelSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.IntermediatePanel.Skins',
#  'CanardIntermediatePanelSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.IntermediatePanel.Spars',
#  'CanardIntermediatePanelStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.IntermediatePanel.Stringers',
#  'CanardLeadingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.LeadingEdgeFlaps',
#  'CanardOuterPanel': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.OuterPanel',
#  'CanardOuterPanelClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.OuterPanel.Clips',
#  'CanardOuterPanelRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.OuterPanel.Ribs',
#  'CanardOuterPanelSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.OuterPanel.Skins',
#  'CanardOuterPanelSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.OuterPanel.Spars',
#  'CanardOuterPanelStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.BasicStructure.OuterPanel.Stringers',
#  'CanardSecondaryStructure': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.SecondaryStructure',
#  'CanardSlats': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.Slats',
#  'CanardSpoilers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.Spoilers',
#  'CanardTrailingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Empennage.Canard.TrailingEdgeFlaps',
#  'CommonSupportEquipment': 'AircraftSystem.CommonSupportEquipment',
#  'ContractorLogisticsSupport': 'AircraftSystem.ContractorLogisticsSupport',
#  'Data': 'AircraftSystem.Data',
#  'DataDeliverables': 'AircraftSystem.Data.DataDeliverables',
#  'DataRepository': 'AircraftSystem.Data.DataRepository',
#  'DataRights': 'AircraftSystem.Data.DataRights',
#  'DevelopmentalTestAndEvaluation': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation',
#  'DevelopmentalTestAndEvaluationCybersecurityTestAndEvaluation': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.CybersecurityTestAndEvaluation',
#  'DevelopmentalTestAndEvaluationFlightTests': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.FlightTests',
#  'DevelopmentalTestAndEvaluationGroundTests': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.GroundTests',
#  'DevelopmentalTestAndEvaluationOtherDtETests': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.OtherDtETests',
#  'DevelopmentalTestAndEvaluationStructuralTests': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.StructuralTests',
#  'DevelopmentalTestAndEvaluationSystemAcceptanceTest': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.SystemAcceptanceTest',
#  'DevelopmentalTestAndEvaluationWindTunnelTests': 'AircraftSystem.SystemTestAndEvaluation.DevelopmentalTestAndEvaluation.WindTunnelTests',
#  'EmergencyEquipment': 'AircraftSystem.AirVehicle.FurnishingsAndEquipment.EmergencyEquipment',
#  'Empennage': 'AircraftSystem.AirVehicle.Airframe.Empennage',
#  'Furnishings': 'AircraftSystem.AirVehicle.FurnishingsAndEquipment.Furnishings',
#  'FurnishingsAndEquipment': 'AircraftSystem.AirVehicle.FurnishingsAndEquipment',
#  'Fuselage': 'AircraftSystem.AirVehicle.Airframe.Fuselage',
#  'FuselageBasicStructure': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure',
#  'FuselageBeams': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Beams',
#  'FuselageBulkheads': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Bulkheads',
#  'FuselageClips': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Clips',
#  'FuselageDoors': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Doors',
#  'FuselageEnclosures': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Enclosures',
#  'FuselageFlooring': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Flooring',
#  'FuselageFloors': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Floors',
#  'FuselageFrames': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Frames',
#  'FuselageLongerons': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Longerons',
#  'FuselageMisc': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Misc',
#  'FuselagePanels': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Panels',
#  'FuselagePartitions': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Partitions',
#  'FuselageRamps': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Ramps',
#  'FuselageSecondaryStructure': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure',
#  'FuselageSkins': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Skins',
#  'FuselageStringers': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Stringers',
#  'FuselageSupports': 'AircraftSystem.AirVehicle.Airframe.Fuselage.BasicStructure.Supports',
#  'FuselageWindows': 'AircraftSystem.AirVehicle.Airframe.Fuselage.SecondaryStructure.Windows',
#  'GroundHostSegment': 'AircraftSystem.GroundHostSegment',
#  'GroundHostSegmentCommandAndControlSubsystem': 'AircraftSystem.GroundHostSegment.CommandAndControlSubsystem',
#  'GroundHostSegmentGroundControlSystems': 'AircraftSystem.GroundHostSegment.GroundControlSystems',
#  'GroundHostSegmentIntegration': 'AircraftSystem.GroundHostSegment.GroundSegmentIntegrationAssemblyTestAndCheckout',
#  'GroundHostSegmentLaunchEquipment': 'AircraftSystem.GroundHostSegment.LaunchEquipment',
#  'GroundHostSegmentOther': 'AircraftSystem.GroundHostSegment.OtherGroundHostSegment',
#  'GroundHostSegmentRecoveryEquipment': 'AircraftSystem.GroundHostSegment.RecoveryEquipment',
#  'GroundHostSegmentSoftwareRelease': 'AircraftSystem.GroundHostSegment.GroundSegmentSoftwareRelease',
#  'GroundHostSegmentTransportVehicles': 'AircraftSystem.GroundHostSegment.TransportVehicles',
#  'GunInstallationsGuns': 'AircraftSystem.AirVehicle.OperatingItems.GunInstallations.Guns',
#  'GunInstallationsSupports': 'AircraftSystem.AirVehicle.OperatingItems.GunInstallations.Supports',
#  'IndustrialFacilities': 'AircraftSystem.IndustrialFacilities',
#  'IndustrialFacilitiesConstructionConversionExpansion': 'AircraftSystem.IndustrialFacilities.ConstructionConversionExpansion',
#  'IndustrialFacilitiesEquipmentAcquisitionOrModernization': 'AircraftSystem.IndustrialFacilities.EquipmentAcquisitionOrModernization',
#  'IndustrialFacilitiesIndustrialFacilitiesMaintenance': 'AircraftSystem.IndustrialFacilities.IndustrialFacilitiesMaintenance',
#  'InitialSparesAndRepairParts': 'AircraftSystem.InitialSparesAndRepairParts',
#  'LoadHandling': 'AircraftSystem.AirVehicle.LoadHandlingSystem.LoadHandling',
#  'LoadHandlingSystem': 'AircraftSystem.AirVehicle.LoadHandlingSystem',
#  'ManufacturingVariation': 'AircraftSystem.AirVehicle.ManufacturingVariation',
#  'MiscellaneousEquipment': 'AircraftSystem.AirVehicle.FurnishingsAndEquipment.MiscellaneousEquipment',
#  'Nacelle': 'AircraftSystem.AirVehicle.Airframe.Nacelle',
#  'NacelleBasicStructure': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure',
#  'NacelleBeams': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Beams',
#  'NacelleBulkheads': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Bulkheads',
#  'NacelleClips': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Clips',
#  'NacelleDoors': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Doors',
#  'NacelleEnclosures': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Enclosures',
#  'NacelleFlooring': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Flooring',
#  'NacelleFloors': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Floors',
#  'NacelleFrames': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Frames',
#  'NacelleLongerons': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Longerons',
#  'NacelleMisc': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Misc',
#  'NacellePanels': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Panels',
#  'NacellePartitions': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Partitions',
#  'NacelleRamps': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Ramps',
#  'NacelleSecondaryStructure': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure',
#  'NacelleSkins': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Skins',
#  'NacelleStringers': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Stringers',
#  'NacelleSupports': 'AircraftSystem.AirVehicle.Airframe.Nacelle.BasicStructure.Supports',
#  'NacelleWindows': 'AircraftSystem.AirVehicle.Airframe.Nacelle.SecondaryStructure.Windows',
#  'OperatingItemsAuxFuelTanks': 'AircraftSystem.AirVehicle.OperatingItems.AuxFuelTanks',
#  'OperatingItemsBaggage': 'AircraftSystem.AirVehicle.OperatingItems.Baggage',
#  'OperatingItemsChaff': 'AircraftSystem.AirVehicle.OperatingItems.Chaff',
#  'OperatingItemsCrew': 'AircraftSystem.AirVehicle.OperatingItems.Crew',
#  'OperatingItemsEngineOil': 'AircraftSystem.AirVehicle.OperatingItems.EngineOil',
#  'OperatingItemsExternalFuelTanks': 'AircraftSystem.AirVehicle.OperatingItems.ExternalFuelTanks',
#  'OperatingItemsFlares': 'AircraftSystem.AirVehicle.OperatingItems.Flares',
#  'OperatingItemsGunInstallations': 'AircraftSystem.AirVehicle.OperatingItems.GunInstallations',
#  'OperatingItemsInternalFuelTanks': 'AircraftSystem.AirVehicle.OperatingItems.InternalFuelTanks',
#  'OperatingItemsLifeRafts': 'AircraftSystem.AirVehicle.OperatingItems.LifeRafts',
#  'OperatingItemsOxygen': 'AircraftSystem.AirVehicle.OperatingItems.Oxygen',
#  'OperatingItemsSurvivalKits': 'AircraftSystem.AirVehicle.OperatingItems.SurvivalKits',
#  'OperatingItemsTrappedOil': 'AircraftSystem.AirVehicle.OperatingItems.TrappedOil',
#  'OperatingItemsUnusableFuel': 'AircraftSystem.AirVehicle.OperatingItems.UnusableFuel',
#  'OperatingItemsWaterInjectionFluid': 'AircraftSystem.AirVehicle.OperatingItems.WaterInjectionFluid',
#  'OperatingItemsWeaponsProvisions': 'AircraftSystem.AirVehicle.OperatingItems.WeaponsProvisions',
#  'OperationalSiteActivation': 'AircraftSystem.OperationalSiteActivation',
#  'OperationalSiteActivationContractorTechnicalSupport': 'AircraftSystem.OperationalSiteActivation.ContractorTechnicalSupport',
#  'OperationalSiteActivationInterimContractorSupport': 'AircraftSystem.OperationalSiteActivation.InterimContractorSupport',
#  'OperationalSiteActivationSiteConstruction': 'AircraftSystem.OperationalSiteActivation.SiteConstruction',
#  'OperationalSiteActivationSiteShipVehicleConversion': 'AircraftSystem.OperationalSiteActivation.SiteShipVehicleConversion',
#  'OperationalSiteActivationSystemAssemblyInstallationAndCheckoutOnSite': 'AircraftSystem.OperationalSiteActivation.SystemAssemblyInstallationAndCheckoutOnSite',
#  'OperationalTestAndEvaluation': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation',
#  'OperationalTestAndEvaluationCybersecurity': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation.CybersecurityTestAndEvaluation',
#  'OperationalTestAndEvaluationFlightTests': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation.FlightTests',
#  'OperationalTestAndEvaluationGroundTests': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation.GroundTests',
#  'OperationalTestAndEvaluationInteroperabilityTesting': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation.InteroperabilityTesting',
#  'OperationalTestAndEvaluationLimitedUserEvaluation': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation.LimitedUserEvaluation',
#  'OperationalTestAndEvaluationOtherOtETests': 'AircraftSystem.SystemTestAndEvaluation.OperationalTestAndEvaluation.OtherOtETests',
#  'PayloadMissionSystemArmamentWeaponsDelivery': 'AircraftSystem.PayloadMissionSystem.ArmamentWeaponsDeliveryPayload',
#  'PayloadMissionSystemElectronicWarfare': 'AircraftSystem.PayloadMissionSystem.ElectronicWarfarePayload',
#  'PayloadMissionSystemIntegration': 'AircraftSystem.PayloadMissionSystem.PayloadIntegrationAssemblyTestAndCheckout',
#  'PayloadMissionSystemOther': 'AircraftSystem.PayloadMissionSystem.OtherPayload',
#  'PayloadMissionSystemReconnaissance': 'AircraftSystem.PayloadMissionSystem.ReconnaissancePayload',
#  'PayloadMissionSystemSoftwareRelease': 'AircraftSystem.PayloadMissionSystem.PayloadSoftwareRelease',
#  'PayloadMissionSystemSurvivability': 'AircraftSystem.PayloadMissionSystem.SurvivabilityPayload',
#  'PeculiarSupportEquipment': 'AircraftSystem.PeculiarSupportEquipment',
#  'ProgramManagement': 'AircraftSystem.ProgramManagement',
#  'ProgramManagementCore': 'AircraftSystem.ProgramManagement.CoreProgramManagement',
#  'ProgramManagementCybersecurity': 'AircraftSystem.ProgramManagement.CybersecurityManagement',
#  'ProgramManagementIntegratedLogisticsSupport': 'AircraftSystem.ProgramManagement.IntegratedLogisticsSupportProgramManagement',
#  'ProgramManagementOther': 'AircraftSystem.ProgramManagement.OtherProgramManagement',
#  'ProgramManagementSoftware': 'AircraftSystem.ProgramManagement.SoftwareProgramManagement',
#  'Propulsion': 'AircraftSystem.AirVehicle.Propulsion',
#  'PropulsionAccessoryGearBoxesDrive': 'AircraftSystem.AirVehicle.Propulsion.AccessoryGearBoxesDrive',
#  'PropulsionDriveSystem': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem',
#  'PropulsionEngine': 'AircraftSystem.AirVehicle.Propulsion.Engine',
#  'PropulsionEngineControls': 'AircraftSystem.AirVehicle.Propulsion.EngineControls',
#  'PropulsionEngineCooling': 'AircraftSystem.AirVehicle.Propulsion.EngineCooling',
#  'PropulsionEngineInstallation': 'AircraftSystem.AirVehicle.Propulsion.EngineInstallation',
#  'PropulsionEtc': 'AircraftSystem.AirVehicle.Propulsion.FuelSystem.Etc',
#  'PropulsionExhaustSystem': 'AircraftSystem.AirVehicle.Propulsion.ExhaustSystem',
#  'PropulsionFuelSystem': 'AircraftSystem.AirVehicle.Propulsion.FuelSystem',
#  'PropulsionGasDrive': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem.GasDrive',
#  'PropulsionGearBoxes': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem.GearBoxes',
#  'PropulsionLubSys': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem.LubSys',
#  'PropulsionLubricatingSystem': 'AircraftSystem.AirVehicle.Propulsion.LubricatingSystem',
#  'PropulsionPlumbing': 'AircraftSystem.AirVehicle.Propulsion.FuelSystem.Plumbing',
#  'PropulsionPropellerFanInstallation': 'AircraftSystem.AirVehicle.Propulsion.PropellerFanInstallation',
#  'PropulsionProtectedTanks': 'AircraftSystem.AirVehicle.Propulsion.FuelSystem.ProtectedTanks',
#  'PropulsionRotorShaft': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem.RotorShaft',
#  'PropulsionRtrBrk': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem.RtrBrk',
#  'PropulsionStartingSystem': 'AircraftSystem.AirVehicle.Propulsion.StartingSystem',
#  'PropulsionTransmissionDrive': 'AircraftSystem.AirVehicle.Propulsion.DriveSystem.TransmissionDrive',
#  'PropulsionUnprotectedTanks': 'AircraftSystem.AirVehicle.Propulsion.FuelSystem.UnprotectedTanks',
#  'PropulsionWaterInjection': 'AircraftSystem.AirVehicle.Propulsion.WaterInjection',
#  'Stabilizer': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer',
#  'StabilizerAccessPanels': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.SecondaryStructure.AccessPanels',
#  'StabilizerAilerons': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.Ailerons',
#  'StabilizerBasicStructure': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure',
#  'StabilizerCenterSection': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.CenterSection',
#  'StabilizerCenterSectionClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.CenterSection.Clips',
#  'StabilizerCenterSectionRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.CenterSection.Ribs',
#  'StabilizerCenterSectionSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.CenterSection.Skins',
#  'StabilizerCenterSectionSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.CenterSection.Spars',
#  'StabilizerCenterSectionStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.CenterSection.Stringers',
#  'StabilizerElevons': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.Elevons',
#  'StabilizerIntermediatePanel': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.IntermediatePanel',
#  'StabilizerIntermediatePanelClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.IntermediatePanel.Clips',
#  'StabilizerIntermediatePanelRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.IntermediatePanel.Ribs',
#  'StabilizerIntermediatePanelSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.IntermediatePanel.Skins',
#  'StabilizerIntermediatePanelSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.IntermediatePanel.Spars',
#  'StabilizerIntermediatePanelStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.IntermediatePanel.Stringers',
#  'StabilizerLeadingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.LeadingEdgeFlaps',
#  'StabilizerOuterPanel': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.OuterPanel',
#  'StabilizerOuterPanelClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.OuterPanel.Clips',
#  'StabilizerOuterPanelRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.OuterPanel.Ribs',
#  'StabilizerOuterPanelSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.OuterPanel.Skins',
#  'StabilizerOuterPanelSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.OuterPanel.Spars',
#  'StabilizerOuterPanelStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.BasicStructure.OuterPanel.Stringers',
#  'StabilizerSecondaryStructure': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.SecondaryStructure',
#  'StabilizerSlats': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.Slats',
#  'StabilizerSpoilers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.Spoilers',
#  'StabilizerTrailingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Empennage.Stabilizer.TrailingEdgeFlaps',
#  'SupportAndHandlingEquipment': 'AircraftSystem.CommonSupportEquipment.SupportAndHandlingEquipment',
#  'SupportAndHandlingEquipmentAirframeHullVehicle': 'AircraftSystem.CommonSupportEquipment.SupportAndHandlingEquipment.AirframeHullVehicle',
#  'SupportAndHandlingEquipmentElectronicsAvionics': 'AircraftSystem.CommonSupportEquipment.SupportAndHandlingEquipment.ElectronicsAvionics',
#  'SupportAndHandlingEquipmentOtherMajorSubsystems': 'AircraftSystem.CommonSupportEquipment.SupportAndHandlingEquipment.OtherMajorSubsystems',
#  'SupportAndHandlingEquipmentPropulsion': 'AircraftSystem.CommonSupportEquipment.SupportAndHandlingEquipment.Propulsion',
#  'SystemTestAndEvaluation': 'AircraftSystem.SystemTestAndEvaluation',
#  'SystemTestAndEvaluationFacilities': 'AircraftSystem.SystemTestAndEvaluation.TestFacilities',
#  'SystemTestAndEvaluationLiveFire': 'AircraftSystem.SystemTestAndEvaluation.LiveFireTestAndEvaluation',
#  'SystemTestAndEvaluationMockUp': 'AircraftSystem.SystemTestAndEvaluation.MockUpsSystemIntegrationLabs',
#  'SystemTestAndEvaluationSupport': 'AircraftSystem.SystemTestAndEvaluation.TestAndEvaluationSupport',
#  'SystemsEngineering': 'AircraftSystem.SystemsEngineering',
#  'SystemsEngineeringCore': 'AircraftSystem.SystemsEngineering.CoreSystemsEngineering',
#  'SystemsEngineeringCybersecurity': 'AircraftSystem.SystemsEngineering.CybersecuritySystemsEngineering',
#  'SystemsEngineeringIntegratedLogisticsSupport': 'AircraftSystem.SystemsEngineering.IntegratedLogisticsSupportSystemsEngineering',
#  'SystemsEngineeringOther': 'AircraftSystem.SystemsEngineering.OtherSystemsEngineering',
#  'SystemsEngineeringSoftware': 'AircraftSystem.SystemsEngineering.SoftwareSystemsEngineering',
#  'TestAndMeasurementEquipment': 'AircraftSystem.PeculiarSupportEquipment.TestAndMeasurementEquipment',
#  'TestAndMeasurementEquipmentAirframeHullVehicle': 'AircraftSystem.CommonSupportEquipment.TestAndMeasurementEquipment.AirframeHullVehicle',
#  'TestAndMeasurementEquipmentElectronicsAvionics': 'AircraftSystem.CommonSupportEquipment.TestAndMeasurementEquipment.ElectronicsAvionics',
#  'TestAndMeasurementEquipmentOtherMajorSubsystems': 'AircraftSystem.CommonSupportEquipment.TestAndMeasurementEquipment.OtherMajorSubsystems',
#  'TestAndMeasurementEquipmentPropulsion': 'AircraftSystem.CommonSupportEquipment.TestAndMeasurementEquipment.Propulsion',
#  'TestAndMeasurementEquipmentTestAndMeasurementEquipment': 'AircraftSystem.CommonSupportEquipment.TestAndMeasurementEquipment',
#  'Training': 'AircraftSystem.Training',
#  'TrainingEquipment': 'AircraftSystem.Training.Equipment',
#  'TrainingFacilities': 'AircraftSystem.Training.Facilities',
#  'TrainingMaintainerInstructionalEquipment': 'AircraftSystem.Training.Equipment.MaintainerInstructionalEquipment',
#  'TrainingMaintainerInstructionalServices': 'AircraftSystem.Training.Services.MaintainerInstructionalServices',
#  'TrainingOperatorInstructionalEquipment': 'AircraftSystem.Training.Equipment.OperatorInstructionalEquipment',
#  'TrainingOperatorInstructionalServices': 'AircraftSystem.Training.Services.OperatorInstructionalServices',
#  'TrainingServices': 'AircraftSystem.Training.Services',
#  'TrainingSoftware': 'AircraftSystem.Training.TrainingSoftware',
#  'VehicleSubsystems': 'AircraftSystem.AirVehicle.VehicleSubsystems',
#  'VehicleSubsystemsAntiIcing': 'AircraftSystem.AirVehicle.VehicleSubsystems.AntiIcingSubsystem',
#  'VehicleSubsystemsAutomaticFlightControl': 'AircraftSystem.AirVehicle.VehicleSubsystems.FlightControlSubsystem.AutomaticFlightControlSystem',
#  'VehicleSubsystemsAuxiliaryPower': 'AircraftSystem.AirVehicle.VehicleSubsystems.AuxiliaryPowerSubsystem',
#  'VehicleSubsystemsCockpitControls': 'AircraftSystem.AirVehicle.VehicleSubsystems.FlightControlSubsystem.CockpitControls',
#  'VehicleSubsystemsControls': 'AircraftSystem.AirVehicle.VehicleSubsystems.FlightControlSubsystem.SystemControls',
#  'VehicleSubsystemsCrewStation': 'AircraftSystem.AirVehicle.VehicleSubsystems.CrewStationSubsystem',
#  'VehicleSubsystemsElectricalAntiIcingSystem': 'AircraftSystem.AirVehicle.VehicleSubsystems.ElectricalAntiIcingSystem',
#  'VehicleSubsystemsEnvironmentalControl': 'AircraftSystem.AirVehicle.VehicleSubsystems.EnvironmentalControlSubsystem',
#  'VehicleSubsystemsFlightControl': 'AircraftSystem.AirVehicle.VehicleSubsystems.FlightControlSubsystem',
#  'VehicleSubsystemsFuel': 'AircraftSystem.AirVehicle.VehicleSubsystems.FuelSubsystem',
#  'VehicleSubsystemsHydraulic': 'AircraftSystem.AirVehicle.VehicleSubsystems.HydraulicSubsystem',
#  'VehicleSubsystemsInstruments': 'AircraftSystem.AirVehicle.VehicleSubsystems.Instruments',
#  'VehicleSubsystemsIntegration': 'AircraftSystem.AirVehicle.VehicleSubsystems.VehicleSubsystemIntegrationAssemblyTestAndCheckout',
#  'VehicleSubsystemsOther': 'AircraftSystem.AirVehicle.VehicleSubsystems.OtherSubsystems',
#  'VehicleSubsystemsPneumatic': 'AircraftSystem.AirVehicle.VehicleSubsystems.PneumaticSubsystem',
#  'VehicleSubsystemsSoftware': 'AircraftSystem.AirVehicle.VehicleSubsystems.VehicleSubsystemSoftware',
#  'Vertical': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical',
#  'VerticalAccessPanels': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.SecondaryStructure.AccessPanels',
#  'VerticalAilerons': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.Ailerons',
#  'VerticalBasicStructure': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure',
#  'VerticalCenterSection': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.CenterSection',
#  'VerticalCenterSectionClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.CenterSection.Clips',
#  'VerticalCenterSectionRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.CenterSection.Ribs',
#  'VerticalCenterSectionSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.CenterSection.Skins',
#  'VerticalCenterSectionSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.CenterSection.Spars',
#  'VerticalCenterSectionStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.CenterSection.Stringers',
#  'VerticalElevons': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.Elevons',
#  'VerticalIntermediatePanel': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.IntermediatePanel',
#  'VerticalIntermediatePanelClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.IntermediatePanel.Clips',
#  'VerticalIntermediatePanelRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.IntermediatePanel.Ribs',
#  'VerticalIntermediatePanelSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.IntermediatePanel.Skins',
#  'VerticalIntermediatePanelSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.IntermediatePanel.Spars',
#  'VerticalIntermediatePanelStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.IntermediatePanel.Stringers',
#  'VerticalLeadingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.LeadingEdgeFlaps',
#  'VerticalOuterPanel': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.OuterPanel',
#  'VerticalOuterPanelClips': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.OuterPanel.Clips',
#  'VerticalOuterPanelRibs': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.OuterPanel.Ribs',
#  'VerticalOuterPanelSkins': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.OuterPanel.Skins',
#  'VerticalOuterPanelSpars': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.OuterPanel.Spars',
#  'VerticalOuterPanelStringers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.BasicStructure.OuterPanel.Stringers',
#  'VerticalSecondaryStructure': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.SecondaryStructure',
#  'VerticalSlats': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.Slats',
#  'VerticalSpoilers': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.Spoilers',
#  'VerticalTrailingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Empennage.Vertical.TrailingEdgeFlaps',
#  'Wing': 'AircraftSystem.AirVehicle.Airframe.Wing',
#  'WingAccessPanels': 'AircraftSystem.AirVehicle.Airframe.Wing.SecondaryStructure.AccessPanels',
#  'WingAilerons': 'AircraftSystem.AirVehicle.Airframe.Wing.Ailerons',
#  'WingBasicStructure': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure',
#  'WingCenterSection': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.CenterSection',
#  'WingCenterSectionClips': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.CenterSection.Clips',
#  'WingCenterSectionRibs': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.CenterSection.Ribs',
#  'WingCenterSectionSkins': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.CenterSection.Skins',
#  'WingCenterSectionSpars': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.CenterSection.Spars',
#  'WingCenterSectionStringers': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.CenterSection.Stringers',
#  'WingElevons': 'AircraftSystem.AirVehicle.Airframe.Wing.Elevons',
#  'WingIntermediatePanel': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.IntermediatePanel',
#  'WingIntermediatePanelClips': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.IntermediatePanel.Clips',
#  'WingIntermediatePanelRibs': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.IntermediatePanel.Ribs',
#  'WingIntermediatePanelSkins': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.IntermediatePanel.Skins',
#  'WingIntermediatePanelSpars': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.IntermediatePanel.Spars',
#  'WingIntermediatePanelStringers': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.IntermediatePanel.Stringers',
#  'WingLeadingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Wing.LeadingEdgeFlaps',
#  'WingOuterPanel': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.OuterPanel',
#  'WingOuterPanelClips': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.OuterPanel.Clips',
#  'WingOuterPanelRibs': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.OuterPanel.Ribs',
#  'WingOuterPanelSkins': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.OuterPanel.Skins',
#  'WingOuterPanelSpars': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.OuterPanel.Spars',
#  'WingOuterPanelStringers': 'AircraftSystem.AirVehicle.Airframe.Wing.BasicStructure.OuterPanel.Stringers',
#  'WingSecondaryStructure': 'AircraftSystem.AirVehicle.Airframe.Wing.SecondaryStructure',
#  'WingSlats': 'AircraftSystem.AirVehicle.Airframe.Wing.Slats',
#  'WingSpoilers': 'AircraftSystem.AirVehicle.Airframe.Wing.Spoilers',
#  'WingTrailingEdgeFlaps': 'AircraftSystem.AirVehicle.Airframe.Wing.TrailingEdgeFlaps'}

# %% [markdown]
# The `extract_nacelle_geometry()` function extracts the geometry of the nacelle component using the `get_nested_attr()` function.

# %%
# Extract the nacelle parameters
nacelle_parameters = extract_nacelle_parameters(adh, aliases)
# Out:
# Extracting parameters using path: AircraftSystem.AirVehicle.Airframe.Nacelle.parameters

# %%
pprint.pprint(nacelle_parameters, width=120)
# Out:
# {'diameter': 1.0, 'length': 2.0, 'material': 'Aluminum Alloy', 'weight': 500.0}

# %% [markdown]
# The `scale_nacelle_geometry()` function scales the extracted geometry by a specified factor (e.g., 10%).

# %%
# Extract the nacelle geometry
nacelle_geometry = extract_nacelle_geometry(adh, aliases)
# Out:
# Extracting geometry using path: AircraftSystem.AirVehicle.Airframe.Nacelle.geometry

# %%
pprint.pprint(nacelle_geometry, width=120)
# Out:
# {'cross_sections': [{'lower_curve': {'degree': 3,
#                                      'points': [{'x': 0.0, 'y': 0.5, 'z': 0.0},
#                                                 {'x': 0.0, 'y': 0.0, 'z': -0.4},
#                                                 {'x': 0.0, 'y': -0.5, 'z': 0.0}]},
#                      'station': 0.0,
#                      'upper_curve': {'degree': 3,
#                                      'points': [{'x': 0.0, 'y': 0.5, 'z': 0.0},
#                                                 {'x': 0.0, 'y': 0.0, 'z': 0.4},
#                                                 {'x': 0.0, 'y': -0.5, 'z': 0.0}]}},
#                     {'lower_curve': {'degree': 3,
#                                      'points': [{'x': 0.5, 'y': 0.5, 'z': 0.0},
#                                                 {'x': 0.5, 'y': 0.0, 'z': -0.5},
#                                                 {'x': 0.5, 'y': -0.5, 'z': 0.0}]},
#                      'station': 1.0,
#                      'upper_curve': {'degree': 3,
#                                      'points': [{'x': 0.5, 'y': 0.5, 'z': 0.0},
#                                                 {'x': 0.5, 'y': 0.0, 'z': 0.5},
#                                                 {'x': 0.5, 'y': -0.5, 'z': 0.0}]}},
#                     {'lower_curve': {'degree': 3,
#                                      'points': [{'x': 1.0, 'y': 0.5, 'z': 0.0},
#                                                 {'x': 1.0, 'y': 0.0, 'z': -0.3},
#                                                 {'x': 1.0, 'y': -0.5, 'z': 0.0}]},
#                      'station': 2.0,
#                      'upper_curve': {'degree': 3,
#                                      'points': [{'x': 1.0, 'y': 0.5, 'z': 0.0},
#                                                 {'x': 1.0, 'y': 0.0, 'z': 0.3},
#                                                 {'x': 1.0, 'y': -0.5, 'z': 0.0}]}}],
#  'reference_axis': {'degree': 3,
#                     'points': [{'x': 1.0, 'y': 1.0, 'z': 1.0},
#                                {'x': 1.0, 'y': 1.0, 'z': 1.0},
#                                {'x': 1.0, 'y': 1.0, 'z': 1.0}]}}

# %% [markdown]
# ### 5. Updating and Saving the Modified Data

# %% [markdown]
# The scaled nacelle geometry is updated within the data hierarchy using the put_nested_attr function.

# %%
# Scale the nacelle geometry by 10%
scaled_nacelle_geometry = scale_nacelle_geometry(nacelle_geometry, 1.1)

# %% [markdown]
# The updated data hierarchy is saved to a new JSON file (revised_aircraft_system.json).

# %%
# Update the ADH with the scaled nacelle geometry
put_nested_attr(adh, aliases["Nacelle"] + ".geometry", scaled_nacelle_geometry)

# Write the updated ADH to a new JSON file
with open("revised_aircraft_system.json", "w") as file:
    json.dump(adh.model_dump(), file, indent=4)

# %% [markdown]
# ### 6. Visualizing the Nacelle Geometry

# %% [markdown]
# The `draw_nacelle_geometry()` function visualizes the scaled nacelle geometry using Matplotlib, providing a graphical representation of the reference axis and cross-sections.

# %%
# Draw the scaled nacelle geometry
draw_nacelle_geometry(scaled_nacelle_geometry)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The Nacelle Demo v2 demonstrates the process of loading, manipulating, and visualizing the geometry of a nacelle component within an aircraft system. By using Pydantic models for data validation and parsing, and by implementing functions to traverse and modify nested attributes, the demonstration provides a comprehensive example of working with complex data hierarchies in Python.
